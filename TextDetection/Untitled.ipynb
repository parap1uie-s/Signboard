# %%
import pandas as pd
from PIL import Image
import numpy as np
import os
from Model import *
from Utils import TestDataGen
import matplotlib.pyplot as plt

% matplotlib inline
# Out:
# d:\program files\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
datapath = "../../../Project/Signboard/datasets/"

# %%
model = get_cam_model()
model.load_weights("text_detection.h5", by_name=True)

# %%
gen = TestDataGen(datapath, 224,224, batch_size=1)

# %%
Img, filepath = next(gen)

# %%
Img = np.expand_dims(np.array(Image.open("1.jpg").resize((224,height),Image.ANTIALIAS) ),axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-8f2425a6e6e0> in <module>()
# ----> 1 Img = np.expand_dims(np.array(Image.open("1.jpg").resize(224,224)),axis=0)
#
# d:\program files\python36\lib\site-packages\PIL\Image.py in resize(self, size, resample, box)
#    1720                 NEAREST, BILINEAR, BICUBIC, LANCZOS, BOX, HAMMING,
#    1721         ):
# -> 1722             raise ValueError("unknown resampling filter")
#    1723
#    1724         size = tuple(size)
#
# ValueError: unknown resampling filter

# %%
Image.open("1.jpg").resize(224,224)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5d5028347c54> in <module>()
# ----> 1 Image.open("1.jpg").resize(224,224)
#
# d:\program files\python36\lib\site-packages\PIL\Image.py in resize(self, size, resample, box)
#    1720                 NEAREST, BILINEAR, BICUBIC, LANCZOS, BOX, HAMMING,
#    1721         ):
# -> 1722             raise ValueError("unknown resampling filter")
#    1723
#    1724         size = tuple(size)
#
# ValueError: unknown resampling filter

# %%
res = model.predict(Img)

# %%
print(res[0].shape)
# Out:
# (224, 224, 2)

# %% [markdown]
# ## plt.imshow(res[0][...,1])

# %%
plt.imshow(Img[0])
